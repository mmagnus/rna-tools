# %%
from rna_tools.rna_tools_lib import *

# %%
s = RNAStructure('../rna_tools/input/1I9V_A.pdb')

# %%
s.is_pdb()
# Out:
# True

# %%
from rna_tools.tools.rna_alignment import rna_alignment

# %%
alignment = rna_alignment.RNAalignment(fetch="RF00167")

# %%
alignment.plot()
# Out:
# Rchie: plot saved to rchie.png

# %%
alignment.cols[0:10]
# Out:
# SingleLetterAlphabet() alignment with 133 rows and 10 columns
# UUACAAUAUA X83878.1/168-267
# ---AAAAUAA AF270087.1/2580-2679
# AAUCGUCUAC AL596165.1/154156-154057
# AUAACUUAAA AL596170.1/223345-223246
# AAUGAAUCAC AB008757.1/115-16
# ---GAAAUCA U51115.1/15592-15691
# AAUCCGCUAC AL591975.1/251119-251020
# AUAACUUAAA AL591981.1/205922-205823
# GACAUAAUUA ABDP01000013.1/128838-128739
# AGAUAAUAUA CP000764.1/271074-271175
# CUUCGAAAAG AAEQ01000019.1/51159-51260
# AGAUAAUAUA AAEK01000017.1/86437-86538
# AAAGAAUAAU CP000001.1/309094-309195
# AAAAUUGAAU CP000410.1/1642356-1642451
# GUAUAAUCGC AAWP01000021.1/27378-27279
# AAAAAGUUAA CP000721.1/2204674-2204778
# CUCAGUCGAA CP000724.1/951516-951617
# AAGUUACCGC AANE01000012.1/49153-49054
# ...
# AUACAAAGUG CP003056.1/1737361-1737461
