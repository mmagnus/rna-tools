# %%
import nglview
import rna_pdb_tools.Seq as Seq
import rna_pdb_tools.BlastPDB
from rna_pdb_tools.BlastPDB import BlastPDB
reload(rna_pdb_tools.BlastPDB);
reload(Seq);

# %%
seq = Seq.Seq("GGGGCGCGGCGCUCAUUCCUGCGCAAGCAGGGCAAGGCCCAGUCCCGUGCAAGCCGGGACCGCCCC")

# %%
seq
# Out:
# GGGGCGCGGCGCUCAUUCCUGCGCAAGCAGGGCAAGGCCCAGUCCCGUGCAAGCCGGGACCGCCCC

# %% [markdown]
# # Secondary structure prediction

# %%
print seq.predict_ss()
# Out:
# ((((((.((.(((...((((((....))))))...))))).((((((.......))))))))))))

# %%
print seq.predict_ss(method='RNAsubopt')
# Out:
# GGGGCGCGGCGCUCAUUCCUGCGCAAGCAGGGCAAGGCCCAGUCCCGUGCAAGCCGGGACCGCCCC  -3490    100
# (((((((.((((........))))..)).((((...)))).((((((.......)))))).))))) -34.40
# (((((((.((((........))))..)).((((...)))).((((((.(....))))))).))))) -34.40
# ((((((.((.(((...((((((....))))))...))))).(((((((....)).))))))))))) -33.90
# ((((((.((.(((...((((((....))))))...))))).((((((.......)))))))))))) -34.90
# ((((((.((.(((...((((((....))))))...))))).((((((.(....))))))))))))) -34.90
# ((((((.((.(((...((((((....))))))...))))).(((((((....).)))))))))))) -33.90
# ((((((.(((.((...((((((....))))))..)))))..((((((.......)))))))))))) -33.90
# ((((((.(((.((...((((((....))))))..)))))..((((((.(....))))))))))))) -33.90

# %%
print seq.predict_ss(method='ipknot')
# Out:
# ((((((.((.(((...((((((....))))))...))))).((((((.......))))))))))))

# %%
print seq.predict_ss(method='centroid_fold')
# Out:
# ((((((.((.(((...((((((....))))))...))))).((((((.......)))))))))))) (g=1,th=0.5,e=-27.53)

# %%
print seq.predict_ss(method='contextfold')
# Out:
# ((((((....(((...((((((....))))))...)))...((((((.......))))))))))))

# %%
import rna_pdb_tools.RfamSearch as rf
#reload(rf)

#seq = Seq.Seq("GGGUCAGGCCGGCGAAAGUCGCCACAGUUUGGGGAAAGCUGUGCAGCCUGUAACCCCCCCACGAAAGUGGG")
rs = rf.RfamSearch()
print rs.cmscan(seq)
# Out:
# GCAGGGCAAGGCCCAGUCCCGUGCAAGCCGGGACCGCCCCGCAAGGGGCGCGGCGCUCAUUCCUGC
# # cmscan :: search sequence(s) against a CM database
# # INFERNAL 1.1.2 (July 2016)
# # Copyright (C) 2016 Howard Hughes Medical Institute.
# # Freely distributed under a BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query sequence file:                   /tmp/ss.fa
# # target CM database:                    Rfam.cm
# # sequence reporting threshold:          E-value <= 1
# # number of worker threads:              4
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       test  [L=65]
# Hit scores:
#  rank     E-value  score  bias  modelname  start    end   mdl trunc   gc  description
#  ----   --------- ------ -----  --------- ------ ------   --- ----- ----  -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Hit alignments:
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Internal HMM-only pipeline statistics summary: (run for model(s) with zero basepairs)
# --------------------------------------------------------------------------------------
# Query sequence(s):                                               1  (130 residues searched)
# Target model(s):                                               347  (40911 consensus positions)
# Windows   passing  local HMM SSV           filter:               5  (0.007205); expected (0.02)
# Windows   passing  local HMM MSV      bias filter:               3  (0.004323); expected (0.02)
# Windows   passing  local HMM Viterbi       filter:               0  (0); expected (0.001)
# Windows   passing  local HMM Forward       filter:               0  (0); expected (1e-05)
# Total HMM hits reported:                                         0  (0)
#
# Internal CM pipeline statistics summary:
# ----------------------------------------
# Query sequence(s):                                               1  (130 residues searched)
# Query sequences re-searched for truncated hits:                  1  (378.5 residues re-searched, avg per model)
# Target model(s):                                              2126  (267652 consensus positions)
# Windows   passing  local HMM SSV           filter:            1136  (0.06392); expected (0.35)
# Windows   passing  local HMM Viterbi       filter:                  (off)
# Windows   passing  local HMM Viterbi  bias filter:                  (off)
# Windows   passing  local HMM Forward       filter:             570  (0.0328); expected (0.02)
# Windows   passing  local HMM Forward  bias filter:             451  (0.02601); expected (0.02)
# Windows   passing glocal HMM Forward       filter:             138  (0.008112); expected (0.02)
# Windows   passing glocal HMM Forward  bias filter:             122  (0.00715); expected (0.02)
# Envelopes passing glocal HMM envelope defn filter:             118  (0.006324); expected (0.02)
# Envelopes passing  local CM  CYK           filter:              17  (0.0006004); expected (0.0001)
# Total CM hits reported:                                          0  (0); includes 0 truncated hit(s)
#
# Total CM and HMM hits reported:                                  0
#
# # CPU time: 4.46u 0.47s 00:00:04.93 Elapsed: 00:00:02.36
# //
# [ok]

# %% [markdown]
# # PDB Blast search

# %%
p = BlastPDB(seq.seq)
p.search()
print p.result
# Out:
# <HTML>
# <TITLE>BLAST Search Results</TITLE>
# <BODY BGCOLOR="#FFFFFF" LINK="#0000FF" VLINK="#660099" ALINK="#660099">
# <PRE>
# <b>BLASTN 2.2.18 [Mar-02-2008]</b>
#
#
# <b><a href="http://www.ncbi.nlm.nih.gov/entrez/query.fcgi?db=PubMed&cmd=Retrieve&list_uids
# =9254694&dopt=Citation">Reference</a>:</b>
# Altschul, Stephen F., Thomas L. Madden, Alejandro A. Sch&auml;ffer,
# Jinghui Zhang, Zheng Zhang, Webb Miller, and David J. Lipman (1997),
# "Gapped BLAST and PSI-BLAST: a new generation of protein database search
# programs",  Nucleic Acids Res. 25:3389-3402.
#
# <b>Query=</b> UNKNOWN_SEQUENCE
#          (65 letters)
#
# <b>Database:</b> pdb_nucleotide
#            15,787 sequences; 2,694,141 total letters
#
# Searching..................................................done
#
# <PRE>
#
#
#                                                                  Score    E
# Sequences producing significant alignments:                      (bits) Value
#
# 5J8B:1:A|pdbid|entity|chain(s)|sequence                               <a href = #15237> 24</a>   6.2
# 5J4D:2:B,GB|pdbid|entity|chain(s)|sequence                            <a href = #15214> 24</a>   6.2
# 5J4C:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #15209> 24</a>   6.2
# 5J4B:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #15203> 24</a>   6.2
# 5J3C:1:RA,YA|pdbid|entity|chain(s)|sequence                           <a href = #15194> 24</a>   6.2
# 5J30:1:RA,YA|pdbid|entity|chain(s)|sequence                           <a href = #15188> 24</a>   6.2
# 5IMR:23:D|pdbid|entity|chain(s)|sequence                              <a href = #15032> 24</a>   6.2
# 5IMQ:7:D|pdbid|entity|chain(s)|sequence                               <a href = #15027> 24</a>   6.2
# 5IBB:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14998> 24</a>   6.2
# 5IB8:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14990> 24</a>   6.2
# 5IB7:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14982> 24</a>   6.2
# 5HD1:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14918> 24</a>   6.2
# 5HCR:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14913> 24</a>   6.2
# 5HCQ:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14908> 24</a>   6.2
# 5HCP:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14903> 24</a>   6.2
# 5HAU:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14893> 24</a>   6.2
# 5FDV:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14725> 24</a>   6.2
# 5FDU:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14722> 24</a>   6.2
# 5F8K:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14694> 24</a>   6.2
# 5EL7:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14626> 24</a>   6.2
# 5EL6:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14618> 24</a>   6.2
# 5EL5:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14611> 24</a>   6.2
# 5EL4:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14602> 24</a>   6.2
# 5E81:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14551> 24</a>   6.2
# 5E7K:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #14544> 24</a>   6.2
# 5DOY:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14459> 24</a>   6.2
# 5DOX:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #14453> 24</a>   6.2
# 5DFE:4:RA,YA|pdbid|entity|chain(s)|sequence                           <a href = #14394> 24</a>   6.2
# 5D8B:51:VC,ZC|pdbid|entity|chain(s)|sequence                          <a href = #14324> 24</a>   6.2
# 5CZP:1:RA,YA|pdbid|entity|chain(s)|sequence                           <a href = #14282> 24</a>   6.2
# 5AA0:1:AA|pdbid|entity|chain(s)|sequence                              <a href = #13948> 24</a>   6.2
# 5A9Z:1:AA|pdbid|entity|chain(s)|sequence                              <a href = #13943> 24</a>   6.2
# 4ZSN:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #13896> 24</a>   6.2
# 4ZER:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #13867> 24</a>   6.2
# 4Z8C:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #13854> 24</a>   6.2
# 4Z3S:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #13796> 24</a>   6.2
# 4YZV:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #13770> 24</a>   6.2
# 4YPB:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #13742> 24</a>   6.2
# 4Y4P:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #13629> 24</a>   6.2
# 4Y4O:1:1A,2A|pdbid|entity|chain(s)|sequence                           <a href = #13623> 24</a>   6.2
# 4XEJ:51:A23S,B23S|pdbid|entity|chain(s)|sequence                      <a href = #13532> 24</a>   6.2
# 4WZO:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13449> 24</a>   6.2
# 4WZD:24:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13435> 24</a>   6.2
# 4WU1:24:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13411> 24</a>   6.2
# 4WT1:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13382> 24</a>   6.2
# 4WSM:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13375> 24</a>   6.2
# 4WSD:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13368> 24</a>   6.2
# 4WRO:5:14,1H|pdbid|entity|chain(s)|sequence                           <a href = #13352> 24</a>   6.2
# 4WRA:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13346> 24</a>   6.2
# 4WR6:25:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13338> 24</a>   6.2
# 4WQY:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #13327> 24</a>   6.2
# 4WQU:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #13322> 24</a>   6.2
# 4WQR:26:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13315> 24</a>   6.2
# 4WQF:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #13307> 24</a>   6.2
# 4WQ1:25:14,1H|pdbid|entity|chain(s)|sequence                          <a href = #13303> 24</a>   6.2
# 4WPO:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #13295> 24</a>   6.2
# 4W4G:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #13225> 24</a>   6.2
# 4W2I:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13220> 24</a>   6.2
# 4W2H:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13214> 24</a>   6.2
# 4W2G:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13208> 24</a>   6.2
# 4W2F:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13202> 24</a>   6.2
# 4W2E:1:A|pdbid|entity|chain(s)|sequence                               <a href = #13194> 24</a>   6.2
# 4W29:59:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13187> 24</a>   6.2
# 4V9S:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13184> 24</a>   6.2
# 4V9R:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13179> 24</a>   6.2
# 4V9Q:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #13173> 24</a>   6.2
# 4V9N:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13163> 24</a>   6.2
# 4V9M:58:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13156> 24</a>   6.2
# 4V9L:59:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13151> 24</a>   6.2
# 4V9K:59:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13146> 24</a>   6.2
# 4V9J:60:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13140> 24</a>   6.2
# 4V9I:26:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13138> 24</a>   6.2
# 4V9H:25:BA|pdbid|entity|chain(s)|sequence                             <a href = #13130> 24</a>   6.2
# 4V9B:24:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13108> 24</a>   6.2
# 4V9A:24:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13103> 24</a>   6.2
# 4V97:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13100> 24</a>   6.2
# 4V95:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13094> 24</a>   6.2
# 4V90:35:BA|pdbid|entity|chain(s)|sequence                             <a href = #13084> 24</a>   6.2
# 4V8X:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13067> 24</a>   6.2
# 4V8U:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13060> 24</a>   6.2
# 4V8Q:11:AA|pdbid|entity|chain(s)|sequence                             <a href = #13047> 24</a>   6.2
# 4V8O:35:BA|pdbid|entity|chain(s)|sequence                             <a href = #13039> 24</a>   6.2
# 4V8N:35:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13034> 24</a>   6.2
# 4V8J:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13018> 24</a>   6.2
# 4V8I:23:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13012> 24</a>   6.2
# 4V8H:23:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13009> 24</a>   6.2
# 4V8G:23:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #13006> 24</a>   6.2
# 4V8F:1:AA,DA|pdbid|entity|chain(s)|sequence                           <a href = #13002> 24</a>   6.2
# 4V8E:1:AA,CA|pdbid|entity|chain(s)|sequence                           <a href = #12996> 24</a>   6.2
# 4V8D:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12991> 24</a>   6.2
# 4V8C:1:AA,BA|pdbid|entity|chain(s)|sequence                           <a href = #12984> 24</a>   6.2
# 4V8B:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12979> 24</a>   6.2
# 4V8A:1:AA,BA|pdbid|entity|chain(s)|sequence                           <a href = #12972> 24</a>   6.2
# 4V87:1:AA,DA|pdbid|entity|chain(s)|sequence                           <a href = #12960> 24</a>   6.2
# 4V84:23:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12950> 24</a>   6.2
# 4V83:23:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12946> 24</a>   6.2
# 4V7P:25:BA,CA|pdbid|entity|chain(s)|sequence                          <a href = #12908> 24</a>   6.2
# 4V7M:27:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12902> 24</a>   6.2
# 4V7L:27:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12894> 24</a>   6.2
# 4V7K:57:AA,BA|pdbid|entity|chain(s)|sequence                          <a href = #12884> 24</a>   6.2
# 4V7J:57:AA,BA|pdbid|entity|chain(s)|sequence                          <a href = #12878> 24</a>   6.2
# 4V6G:24:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12680> 24</a>   6.2
# 4V6F:1:AA|pdbid|entity|chain(s)|sequence                              <a href = #12677> 24</a>   6.2
# 4V6F:55:DA|pdbid|entity|chain(s)|sequence                             <a href = #12673> 24</a>   6.2
# 4V6A:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12652> 24</a>   6.2
# 4V67:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12632> 24</a>   6.2
# 4V63:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12614> 24</a>   6.2
# 4V5S:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12402> 24</a>   6.2
# 4V5R:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12396> 24</a>   6.2
# 4V5Q:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12390> 24</a>   6.2
# 4V5P:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12384> 24</a>   6.2
# 4V5N:35:BA|pdbid|entity|chain(s)|sequence                             <a href = #12377> 24</a>   6.2
# 4V5M:35:BA|pdbid|entity|chain(s)|sequence                             <a href = #12372> 24</a>   6.2
# 4V5L:36:BA|pdbid|entity|chain(s)|sequence                             <a href = #12367> 24</a>   6.2
# 4V5K:35:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12361> 24</a>   6.2
# 4V5J:35:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12355> 24</a>   6.2
# 4V5G:36:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12345> 24</a>   6.2
# 4V5F:35:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12339> 24</a>   6.2
# 4V5E:35:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #12334> 24</a>   6.2
# 4V4Z:25:BA|pdbid|entity|chain(s)|sequence                             <a href = #12278> 24</a>   6.2
# 4V4Y:24:BA|pdbid|entity|chain(s)|sequence                             <a href = #12269> 24</a>   6.2
# 4V4X:24:BA|pdbid|entity|chain(s)|sequence                             <a href = #12264> 24</a>   6.2
# 4V4T:26:BA|pdbid|entity|chain(s)|sequence                             <a href = #12255> 24</a>   6.2
# 4V4S:27:BA|pdbid|entity|chain(s)|sequence                             <a href = #12249> 24</a>   6.2
# 4V4R:27:BA|pdbid|entity|chain(s)|sequence                             <a href = #12243> 24</a>   6.2
# 4V4P:2:AA|pdbid|entity|chain(s)|sequence                              <a href = #12231> 24</a>   6.2
# 4V4J:1:w|pdbid|entity|chain(s)|sequence                               <a href = #12220> 24</a>   6.2
# 4V4I:1:w|pdbid|entity|chain(s)|sequence                               <a href = #12214> 24</a>   6.2
# 4V42:25:BA|pdbid|entity|chain(s)|sequence                             <a href = #12184> 24</a>   6.2
# 4TUE:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11881> 24</a>   6.2
# 4TUD:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11874> 24</a>   6.2
# 4TUC:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11867> 24</a>   6.2
# 4TUB:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11860> 24</a>   6.2
# 4TUA:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11853> 24</a>   6.2
# 4P70:22:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11364> 24</a>   6.2
# 4P6F:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #11357> 24</a>   6.2
# 4LT8:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10916> 24</a>   6.2
# 4LSK:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10907> 24</a>   6.2
# 4LNT:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10893> 24</a>   6.2
# 4LFZ:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10873> 24</a>   6.2
# 4LEL:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10855> 24</a>   6.2
# 4L71:22:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10834> 24</a>   6.2
# 4L47:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #10822> 24</a>   6.2
# 1VY7:26:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #3079> 24</a>   6.2
# 1VY6:25:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #3072> 24</a>   6.2
# 1VY5:26:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #3066> 24</a>   6.2
# 1VY4:26:BA,DA|pdbid|entity|chain(s)|sequence                          <a href = #3059> 24</a>   6.2
# 1VVJ:25:RA,YA|pdbid|entity|chain(s)|sequence                          <a href = #3052> 24</a>   6.2
# 1ML5:4:a|pdbid|entity|chain(s)|sequence                               <a href = #1790> 24</a>   6.2
# </PRE>
# <PRE>
# ><a name = 15237></a>5J8B:1:A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 15214></a>5J4D:2:B,GB|pdbid|entity|chain(s)|sequence
#           Length = 2880
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 561 gccccgcaaggg 572
# </PRE>
#
#
# <PRE>
# ><a name = 15209></a>5J4C:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 15203></a>5J4B:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 15194></a>5J3C:1:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 15188></a>5J30:1:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 15032></a>5IMR:23:D|pdbid|entity|chain(s)|sequence
#           Length = 2893
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 15027></a>5IMQ:7:D|pdbid|entity|chain(s)|sequence
#           Length = 2893
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 14998></a>5IBB:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14990></a>5IB8:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14982></a>5IB7:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14918></a>5HD1:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14913></a>5HCR:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14908></a>5HCQ:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14903></a>5HCP:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14893></a>5HAU:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14725></a>5FDV:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14722></a>5FDU:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14694></a>5F8K:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14626></a>5EL7:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14618></a>5EL6:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14611></a>5EL5:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14602></a>5EL4:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14551></a>5E81:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14544></a>5E7K:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 14459></a>5DOY:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14453></a>5DOX:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14394></a>5DFE:4:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 14324></a>5D8B:51:VC,ZC|pdbid|entity|chain(s)|sequence
#           Length = 2893
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 14282></a>5CZP:1:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13948></a>5AA0:1:AA|pdbid|entity|chain(s)|sequence
#           Length = 2889
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13943></a>5A9Z:1:AA|pdbid|entity|chain(s)|sequence
#           Length = 2889
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13896></a>4ZSN:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13867></a>4ZER:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13854></a>4Z8C:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13796></a>4Z3S:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13770></a>4YZV:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13742></a>4YPB:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13629></a>4Y4P:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13623></a>4Y4O:1:1A,2A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13532></a>4XEJ:51:A23S,B23S|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13449></a>4WZO:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13435></a>4WZD:24:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13411></a>4WU1:24:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13382></a>4WT1:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13375></a>4WSM:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13368></a>4WSD:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13352></a>4WRO:5:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13346></a>4WRA:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2918
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 566 gccccgcaaggg 577
# </PRE>
#
#
# <PRE>
# ><a name = 13338></a>4WR6:25:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13327></a>4WQY:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13322></a>4WQU:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13315></a>4WQR:26:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2917
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13307></a>4WQF:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13303></a>4WQ1:25:14,1H|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13295></a>4WPO:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13225></a>4W4G:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13220></a>4W2I:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13214></a>4W2H:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13208></a>4W2G:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13202></a>4W2F:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13194></a>4W2E:1:A|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13187></a>4W29:59:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13184></a>4V9S:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13179></a>4V9R:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13173></a>4V9Q:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13163></a>4V9N:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13156></a>4V9M:58:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13151></a>4V9L:59:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13146></a>4V9K:59:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13140></a>4V9J:60:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 13138></a>4V9I:26:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13130></a>4V9H:25:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13108></a>4V9B:24:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13103></a>4V9A:24:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 13100></a>4V97:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13094></a>4V95:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13084></a>4V90:35:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13067></a>4V8X:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2848
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 558 gccccgcaaggg 569
# </PRE>
#
#
# <PRE>
# ><a name = 13060></a>4V8U:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13047></a>4V8Q:11:AA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13039></a>4V8O:35:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13034></a>4V8N:35:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13018></a>4V8J:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 13012></a>4V8I:23:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13009></a>4V8H:23:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2913
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 561 gccccgcaaggg 572
# </PRE>
#
#
# <PRE>
# ><a name = 13006></a>4V8G:23:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 13002></a>4V8F:1:AA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12996></a>4V8E:1:AA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12991></a>4V8D:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12984></a>4V8C:1:AA,BA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12979></a>4V8B:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12972></a>4V8A:1:AA,BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 12960></a>4V87:1:AA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12950></a>4V84:23:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 12946></a>4V83:23:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 12908></a>4V7P:25:BA,CA|pdbid|entity|chain(s)|sequence
#           Length = 2879
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 12902></a>4V7M:27:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 12894></a>4V7L:27:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 12884></a>4V7K:57:AA,BA|pdbid|entity|chain(s)|sequence
#           Length = 2848
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 558 gccccgcaaggg 569
# </PRE>
#
#
# <PRE>
# ><a name = 12878></a>4V7J:57:AA,BA|pdbid|entity|chain(s)|sequence
#           Length = 2848
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 558 gccccgcaaggg 569
# </PRE>
#
#
# <PRE>
# ><a name = 12680></a>4V6G:24:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2898
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 560 gccccgcaaggg 571
# </PRE>
#
#
# <PRE>
# ><a name = 12677></a>4V6F:1:AA|pdbid|entity|chain(s)|sequence
#           Length = 2909
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 562 gccccgcaaggg 573
# </PRE>
#
#
# <PRE>
# ><a name = 12673></a>4V6F:55:DA|pdbid|entity|chain(s)|sequence
#           Length = 2912
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12652></a>4V6A:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 12632></a>4V67:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2894
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12614></a>4V63:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2894
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12402></a>4V5S:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12396></a>4V5R:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12390></a>4V5Q:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12384></a>4V5P:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12377></a>4V5N:35:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12372></a>4V5M:35:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12367></a>4V5L:36:BA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12361></a>4V5K:35:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2848
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 558 gccccgcaaggg 569
# </PRE>
#
#
# <PRE>
# ><a name = 12355></a>4V5J:35:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12345></a>4V5G:36:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12339></a>4V5F:35:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 12334></a>4V5E:35:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2901
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 558 gccccgcaaggg 569
# </PRE>
#
#
# <PRE>
# ><a name = 12278></a>4V4Z:25:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12269></a>4V4Y:24:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12264></a>4V4X:24:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12255></a>4V4T:26:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12249></a>4V4S:27:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12243></a>4V4R:27:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12231></a>4V4P:2:AA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12220></a>4V4J:1:w|pdbid|entity|chain(s)|sequence
#           Length = 2889
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12214></a>4V4I:1:w|pdbid|entity|chain(s)|sequence
#           Length = 2889
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 12184></a>4V42:25:BA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
# ><a name = 11881></a>4TUE:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 11874></a>4TUD:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 11867></a>4TUC:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 11860></a>4TUB:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 11853></a>4TUA:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 11364></a>4P70:22:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 11357></a>4P6F:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 10916></a>4LT8:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10907></a>4LSK:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10893></a>4LNT:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10873></a>4LFZ:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10855></a>4LEL:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10834></a>4L71:22:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 10822></a>4L47:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 3079></a>1VY7:26:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 3072></a>1VY6:25:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 3066></a>1VY5:26:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 3059></a>1VY4:26:BA,DA|pdbid|entity|chain(s)|sequence
#           Length = 2915
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 563 gccccgcaaggg 574
# </PRE>
#
#
# <PRE>
# ><a name = 3052></a>1VVJ:25:RA,YA|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 564 gccccgcaaggg 575
# </PRE>
#
#
# <PRE>
# ><a name = 1790></a>1ML5:4:a|pdbid|entity|chain(s)|sequence
#           Length = 2916
#
#  Score = 24.3 bits (12), Expect = 6.2
#  Identities = 12/12 (100%)
#  Strand = Plus / Plus
#
#
# Query: 36  gccccgcaaggg 47
#            ||||||||||||
# Sbjct: 565 gccccgcaaggg 576
# </PRE>
#
#
# <PRE>
#   Database: pdb_nucleotide
#     Posted date:  Oct 30, 2016  3:26 AM
#   Number of letters in database: 2,694,141
#   Number of sequences in database:  15,787
#
# Lambda     K      H
#     1.37    0.711     1.31
#
# Gapped
# Lambda     K      H
#     1.37    0.711     1.31
#
#
# Matrix: blastn matrix:1 -3
# Gap Penalties: Existence: 5, Extension: 2
# Number of Sequences: 15787
# Number of Hits to DB: 2101
# Number of extensions: 158
# Number of successful extensions: 158
# Number of sequences better than 10.0: 149
# Number of HSP's gapped: 158
# Number of HSP's successfully gapped: 149
# Length of query: 65
# Length of database: 2,694,141
# Length adjustment: 14
# Effective length of query: 51
# Effective length of database: 2,473,123
# Effective search space: 126129273
# Effective search space used: 126129273
# X1: 10 (19.8 bits)
# X2: 15 (29.7 bits)
# X3: 50 (99.1 bits)
# S1: 10 (20.3 bits)
# S2: 12 (24.3 bits)
# </PRE>
# </BODY>
# </HTML>

# %% [markdown]
# # 3D structure analysis

# %%
from rna_pdb_tools.pdb_parser_lib import RNAStructure

fn = "rna_pdb_tools/data/260c8ff6-f24e-4eff-9760-1831407fc770_ALL_thrs5.30A_clust01-000001_AA.pdb"

s = RNAStructure(fn)
print s.get_report()
print s.get_info_chains()
print s.get_head()
#print s.view() # image paste here :-)

# %%
# %%bash
# cd rna_pdb_tools
# ./rna-pdb-tools.py --no_hr --get_seq data/260c8ff6-f24e-4eff-9760-1831407fc770_ALL_thrs5.30A_clust01-000001_AA.pdb

# %% [markdown]
# # RNA 3D structure prediction

# %%
# model using SimRNA
#res = SimRNA(ss,seq.get_ss())

# %%
# fake import, should be 
res = "rna_pdb_tools/data/260c8ff6-f24e-4eff-9760-1831407fc770_ALL_thrs5.30A_clust01-000001_AA.pdb"
# view
view = nglview.show_structure_file(res)
view.add_representation(repr_type='cartoon')
view

# %% [markdown]
# # rna_pdb_tools --get_seq

# %%
# %%bash
# cd rna_pdb_tools
# ./rna-pdb-tools.py --no_hr --get_seq input/5k7c.pdb

# %%
# %%bash
# cd rna_pdb_tools
# ./rna-pdb-tools.py --no_hr --get_seq input/5k7c.pdb
# ./rna-pdb-tools.py --no_hr --get_seq input/tetraloop.pdb
# ./rna-pdb-tools.py --get_seq input/1xjr.pdb
